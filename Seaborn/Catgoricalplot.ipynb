# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
dataset = sns.load_dataset("tips")

# %%
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#count Chart
sns.countplot(x="sex",data=dataset)
plt.title("No of Male and Female")
plt.xlabel("Gender")
plt.show()

# %%
sns.countplot(x="smoker",data=dataset,palette="magma")
plt.title("No of Smoker or Non Smoker")
plt.xlabel("Smoker")
plt.show()
# Out:
# /tmp/ipykernel_4249/540944561.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="smoker",data=dataset,palette="magma")

# %%
sns.countplot(x="day",data=dataset,palette="rocket")
plt.title("Day")
plt.xlabel("Days")
plt.show()
# Out:
# /tmp/ipykernel_4249/2509439783.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="day",data=dataset,palette="rocket")

# %%
sns.countplot(x="time",data=dataset,palette="flare")
plt.title("People visited by time")
plt.xlabel("Time")
plt.show()
# Out:
# /tmp/ipykernel_4249/1388246117.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x="time",data=dataset,palette="flare")

# %%
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.swarmplot(x="day",y="tip",data=dataset,hue="sex")
plt.title("Day vs Tips")
plt.xlabel("Day")
plt.ylabel("Tips")
plt.show()

# %%
sns.pointplot(x="day",y="tip",data=dataset,hue="sex")
plt.title("Day vs Tips")
plt.xlabel("Day")
plt.ylabel("Tips")
plt.show()

# %%
sns.boxplot(x="day",y="tip",data=dataset,hue="sex")
plt.title("Day vs Tips")
plt.xlabel("Day")
plt.ylabel("Tips")
plt.show()

# %%
sns.violinplot(x="day",y="tip",data=dataset,hue="sex")
plt.title("Day vs Tips")
plt.xlabel("Day")
plt.ylabel("Tips")
plt.show()

# %%
sns.catplot(x="day",y="tip",data=dataset,kind="strip", hue="sex")
plt.title("Day vs Tips")
plt.xlabel("Day")
plt.ylabel("Tips")
plt.show()
